# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/final-year-project/blob/main/cascade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Mounted at /content/gdrive

# %%
# !pip install medpy
# Out:
# Collecting medpy
#   Downloading MedPy-0.4.0.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 6.9 MB/s
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from medpy) (1.4.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from medpy) (1.19.5)
# Collecting SimpleITK>=1.1.0
#   Downloading SimpleITK-2.1.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (48.4 MB)
#      |████████████████████████████████| 48.4 MB 8.6 kB/s
# Building wheels for collected packages: medpy
#   Building wheel for medpy (setup.py) ... done
#   Created wheel for medpy: filename=MedPy-0.4.0-cp37-cp37m-linux_x86_64.whl size=754470 sha256=c47bd26f9138fb2105485ee017b5a85ae0c223d76b5eedfd22c05d52b125a8a7
#   Stored in directory: /root/.cache/pip/wheels/b0/57/3a/da1183f22a6afb42e11138daa6a759de233fd977a984333602
# Successfully built medpy
# Installing collected packages: SimpleITK, medpy
# Successfully installed SimpleITK-2.1.1 medpy-0.4.0

# %%
# !git clone https://github.com/ZFTurbo/volumentations
# Out:
# Cloning into 'volumentations'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 36 (delta 8), reused 32 (delta 7), pack-reused 0
# Unpacking objects: 100% (36/36), done.

# %%
pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.14.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 8.4 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.14.0

# %%
from zipfile import ZipFile
  
# specifying the zip file name
file_name = "/content/gdrive/MyDrive/results (6).zip"
  
# opening the zip file in READ mode
with ZipFile(file_name, 'r') as zip:
    zip.extractall()

# %%
import numpy as np
t1=np.load('/content/train_0.npy')
ls=[]
for i in t1:
  ls.append('/content/'+'/'.join(i.split('/')[-2:]))

# %%
from zipfile import ZipFile
  
# specifying the zip file name
file_name = "/content/gdrive/MyDrive/BraTS2020_TrainingData.zip"
  
# opening the zip file in READ mode
with ZipFile(file_name, 'r') as zip:
    zip.extractall()

# %%
file_name = "/content/gdrive/MyDrive/BraTS2020_ValidationData.zip"
with ZipFile(file_name, 'r') as zip:
    zip.extractall()

# %%
#remove .csv
ls
# Out:
# ['/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_010',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_110',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_244',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_076',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_141',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_097',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_158',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_095',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_361',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_318',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_324',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_052',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_263',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_294',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_124',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_117',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_365',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_030',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_299',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_209',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_080',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_189',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_314',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_121',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_046',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_196',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_153',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_063',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_210',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_251',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_154',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_125',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_359',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_206',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_185',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_044',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_016',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_115',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_357',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_216',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_341',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_116',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_230',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_090',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_106',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_170',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_309',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_053',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_272',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_202',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_330',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_212',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_122',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_140',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_105',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_332',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_011',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_041',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_138',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_099',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_152',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_300',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_252',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_176',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_040',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_015',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_213',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_312',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_005',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_029',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_271',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_156',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_275',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_147',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_113',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_239',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_329',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_055',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_136',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_208',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_056',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_078',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_001',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_150',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_133',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_109',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_249',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_293',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_311',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_204',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_081',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_159',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_220',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_172',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_287',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_155',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_182',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_353',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_321',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_167',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_086',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_096',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_064',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_326',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_079',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_259',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_092',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_067',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_234',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_022',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_075',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_089',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_254',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_306',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_214',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_247',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_163',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_223',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_295',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_241',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_033',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_250',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_282',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_344',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_102',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_143',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_058',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_123',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_286',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_346',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_093',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_062',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_333',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_094',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_037',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_233',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_351',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_280',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_035',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_057',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_228',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_256',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_188',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_304',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_003',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_023',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_248',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_200',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_184',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_148',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_043',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_319',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_038',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_014',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_267',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_240',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_101',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_068',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_347',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_343',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_175',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_174',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_336',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_192',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_012',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_366',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_315',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_229',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_104',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_032',
#  '/content/MICCAI_BraTS2020_TrainingData/name_mapping.csv',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_305',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_025',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_071',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_335',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_132',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_066',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_194',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_036',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_349',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_084',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_002',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_211',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_203',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_345',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_128',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_074',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_201',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_193',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_061',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_352',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_088',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_098',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_367',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_242',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_129',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_226',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_137',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_186',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_160',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_199',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_183',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_262',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_298',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_232',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_276',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_171',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_261',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_187',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_021',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_362',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_360',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_103',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_069',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_047',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_168',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_301',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_265',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_130',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_338',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_264',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_237',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_221',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_049',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_191',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_296',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_323',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_059',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_111',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_077',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_020',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_085',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_008',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_134',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_018',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_278',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_291',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_164',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_007',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_013',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_348',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_024',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_087',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_151',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_051',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_224',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_288',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_082',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_190',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_019',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_236',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_325',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_231',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_009',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_369',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_270',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_039',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_327',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_308',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_131',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_340',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_135',
#  '/content/MICCAI_BraTS2020_TrainingData/survival_info.csv',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_091',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_165',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_217',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_120',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_139',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_277',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_356',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_269',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_006',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_028',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_017',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_255',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_197',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_144',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_313',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_112',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_283',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_050',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_149',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_072',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_118',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_260',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_290',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_042',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_177',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_126',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_317',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_246',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_181',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_178',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_355',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_285',
#  '/content/MICCAI_BraTS2020_TrainingData/BraTS20_Training_297']

# %%
from medpy.io import load, save
from volumentations.volumentations import RandomCrop
from volumentations.volumentations import *
import tensorflow as tf
import glob
class DataGenerator(tf.keras.utils.Sequence):
  def __init__(self, images,batch_size=1):
    self.images = images        # array of image paths
    self.aug = Compose([
        RandomScale(p=1),
        RandomCrop((16,16,16), p=1),
        Flip(axis=0,p=0.5),
        Flip(axis=1,p=0.5),
        Flip(axis=2,p=0.5)
    ], p=1.0)
    self.on_epoch_end()
    self.batch_size=batch_size

  def __len__(self):
    return int(np.floor(len(self.images) / self.batch_size))

  def on_epoch_end(self):
    self.indexes = np.arange(len(self.images))

  def std(self,img):
    mn=np.mean(img)
    std=np.std(img)
    img=(img-mn)/std
    return img

  def augmentation(self,img,label):
    data = {'image': img, 'mask': label}
    data = self.aug(**data)
    img1,label1=data['image'],data['mask']
    return img1,label1

  def __getitem__(self, index):
    name=self.images[index].split('/')[-1]
    a=load(self.images[index]+'/'+name+'_seg.nii')[0]
    path=self.images[index]+'/'+name
    b=a.copy()
    c=a.copy()
    d=a.copy()
    
    b[b!=1]=0
    c[c!=2]=0
    d[d!=4]=0
    
    c[c!=0]=1
    d[d!=0]=1
    
    img1=load(path+'_t1.nii')[0]
    img2=load(path+'_t2.nii')[0]
    img3=load(path+'_t1ce.nii')[0]
    img4=load(path+'_flair.nii')[0]
    
    img,seg=self.augmentation(self.std(np.stack([img1,img2,img3,img4],-1)),np.stack([b,c,d],-1))
    seg=np.expand_dims(seg,0)
    return np.expand_dims(img,0),[seg,seg,seg]
train=DataGenerator(ls)

# %%
from tensorflow.keras.layers  import *
from tensorflow_addons.layers import *
from tensorflow.keras.models import *
def block(x,l):
    x=GroupNormalization(8)(x)
    x=ReLU()(x)
    x = Conv3D(l,(3,3,3),padding='same')(x)
    return x
def create_model():
    img_input = Input(batch_shape=(None,16,16,16,4))

    x = Conv3D(16,(3,3,3),padding='same')(img_input)
    a = SpatialDropout3D(0.2)(x)

    x = block(a,16)
    x = block(x,16)

    b = Conv3D(32,(2,2,2),strides=(2,2,2))(x)

    x = block(b,32)
    x = block(x,32)


    c = Conv3D(64,(2,2,2),strides=(2,2,2))(x)

    x = block(c,64)
    x = block(x,64)

    d = Conv3D(128,(2,2,2),strides=(2,2,2))(x)

    x = block(d,128)
    x = block(x,128)

    x = Conv3D(64,(1,1,1))(x)
    x = Conv3DTranspose(64, (2,2,2), strides=(2,2,2))(x)
    x = Add()([x,c])

    x = block(x,64)
    x = block(x,64)

    x = Conv3D(32,(1,1,1))(x)
    x = Conv3DTranspose(32, (2,2,2), strides=(2,2,2))(x)
    x = Add()([x,b])

    x = block(x,32)
    x = block(x,32)

    x = Conv3D(16,(1,1,1))(x)
    x = Conv3DTranspose(16, (2,2,2), strides=(2,2,2))(x)
    x = Add()([x,a])

    x = block(x,16)
    x = block(x,16)

    x_mid = Conv3D(3,(1,1,1),activation='sigmoid')(x)

    x = Concatenate()([x_mid,img_input])

    x = Conv3D(32,(3,3,3),padding='same')(x)
    a = SpatialDropout3D(0.2)(x)

    x = block(a,32)
    x = block(x,32)

    b = Conv3D(64,(2,2,2),strides=(2,2,2))(x)

    x = block(b,64)
    x = block(x,64)


    c = Conv3D(128,(2,2,2),strides=(2,2,2))(x)

    x = block(c,128)
    x = block(x,128)

    d = Conv3D(256,(2,2,2),strides=(2,2,2))(x)

    x = block(d,256)
    enc = block(x,256)

    x = Conv3D(128,(1,1,1))(enc)
    x = Conv3DTranspose(128, (2,2,2), strides=(2,2,2))(x)
    x = Add()([x,c])

    x = block(x,128)
    x = block(x,128)

    x = Conv3D(64,(1,1,1))(x)
    x = Conv3DTranspose(64, (2,2,2), strides=(2,2,2))(x)
    x = Add()([x,b])

    x = block(x,64)
    x = block(x,64)

    x = Conv3D(32,(1,1,1))(x)
    x = Conv3DTranspose(32, (2,2,2), strides=(2,2,2))(x)
    x = Add()([x,a])

    x = block(x,32)
    x = block(x,32)

    x_ct = Conv3D(3,(1,1,1),activation='sigmoid')(x)


    x = Conv3D(128,(1,1,1))(enc)
    x = UpSampling3D(size=(2,2,2))(x)
    x = Add()([x,c])

    x = block(x,128)
    x = block(x,128)

    x = Conv3D(64,(1,1,1))(x)
    x = UpSampling3D(size=(2,2,2))(x)
    x = Add()([x,b])

    x = block(x,64)
    x = block(x,64)

    x = Conv3D(32,(1,1,1))(x)
    x = UpSampling3D(size=(2,2,2))(x)
    x = Add()([x,a])

    x = block(x,32)
    x = block(x,32)

    x_ups = Conv3D(3,(1,1,1),activation='sigmoid')(x)


    mod=Model(inputs=[img_input],outputs=[x_mid,x_ct,x_ups])
    return mod

# %%
from tensorflow.keras.optimizers import *
import glob
mod=create_model()
# train=DataGenerator(glob.glob('/content/MICCAI_BraTS2020_TrainingData/*'))
mod.compile(optimizer=Adam(2e-5),loss='bce')
mod.fit_generator(train,workers=8,epochs=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 130/296 [============>.................] - ETA: 1:50:48 - loss: 0.7783 - conv3d_75_loss: 0.4672 - conv3d_97_loss: 0.1911 - conv3d_107_loss: 0.1201
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-19-705952276753> in <module>()
#       4 # train=DataGenerator(glob.glob('/content/MICCAI_BraTS2020_TrainingData/*'))
#       5 mod.compile(optimizer=Adam(2e-5),loss='bce')
# ----> 6 mod.fit_generator(train,workers=8,epochs=1)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1987         use_multiprocessing=use_multiprocessing,
#    1988         shuffle=shuffle,
# -> 1989         initial_epoch=initial_epoch)
#    1990
#    1991   @doc_controls.do_not_generate_docs
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# UnknownError: 2 root error(s) found.
#   (0) Unknown:  ImageLoadingError: The supplied image /content/MICCAI_BraTS2020_TrainingData/survival_info.csv/survival_info.csv_seg.nii does not exist.
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/script_ops.py", line 249, in __call__
#     ret = func(*args)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py", line 645, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 892, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "/usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py", line 822, in wrapped_generator
#     for data in generator_fn():
#
#   File "/usr/local/lib/python3.7/dist-packages/keras/utils/data_utils.py", line 782, in get
#     raise e
#
#   File "/usr/local/lib/python3.7/dist-packages/keras/utils/data_utils.py", line 773, in get
#     inputs = self.queue.get(block=True, timeout=5).get()
#
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 657, in get
#     raise self._value
#
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#
#   File "/usr/local/lib/python3.7/dist-packages/keras/utils/data_utils.py", line 563, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#
#   File "<ipython-input-17-99640fd63481>", line 39, in __getitem__
#     a=load(self.images[index]+'/'+name+'_seg.nii')[0]
#
#   File "/usr/local/lib/python3.7/dist-packages/medpy/io/load.py", line 106, in load
#     raise ImageLoadingError('The supplied image {} does not exist.'.format(image))
#
# medpy.core.exceptions.ImageLoadingError: The supplied image /content/MICCAI_BraTS2020_TrainingData/survival_info.csv/survival_info.csv_seg.nii does not exist.
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
# 	 [[IteratorGetNext/_8]]
#   (1) Unknown:  ImageLoadingError: The supplied image /content/MICCAI_BraTS2020_TrainingData/survival_info.csv/survival_info.csv_seg.nii does not exist.
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/script_ops.py", line 249, in __call__
#     ret = func(*args)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py", line 645, in wrapper
#     return func(*args, **kwargs)
#
#   File "/usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 892, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "/usr/local/lib/python3.7/dist-packages/keras/engine/data_adapter.py", line 822, in wrapped_generator
#     for data in generator_fn():
#
#   File "/usr/local/lib/python3.7/dist-packages/keras/utils/data_utils.py", line 782, in get
#     raise e
#
#   File "/usr/local/lib/python3.7/dist-packages/keras/utils/data_utils.py", line 773, in get
#     inputs = self.queue.get(block=True, timeout=5).get()
#
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 657, in get
#     raise self._value
#
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#
#   File "/usr/local/lib/python3.7/dist-packages/keras/utils/data_utils.py", line 563, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#
#   File "<ipython-input-17-99640fd63481>", line 39, in __getitem__
#     a=load(self.images[index]+'/'+name+'_seg.nii')[0]
#
#   File "/usr/local/lib/python3.7/dist-packages/medpy/io/load.py", line 106, in load
#     raise ImageLoadingError('The supplied image {} does not exist.'.format(image))
#
# medpy.core.exceptions.ImageLoadingError: The supplied image /content/MICCAI_BraTS2020_TrainingData/survival_info.csv/survival_info.csv_seg.nii does not exist.
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]]
# 0 successful operations.
# 0 derived errors ignored. [Op:__inference_train_function_41891]
#
# Function call stack:
# train_function -> train_function
